# %% [markdown]
# #### thought process
# 1. Step one: examine the data to understand the context of what the data is about and be able to provide specific prompts to make ChatGPT understand more

# %%
# import Library
import pandas as pd

# %%
pd.options.display.max_columns = 50 # expand display columns
pd.read_csv('ecommerce-session-bigquery.csv').head(10) # read data
# Out:
#          fullVisitorId channelGrouping     time        country  \
# 0  2515546493837534633  Organic Search   966564         Taiwan
# 1  9361741997835388618  Organic Search   157377         France
# 2  7313828956068851679        Referral   228279  United States
# 3  6036794406403793540  Organic Search  1615618  United States
# 4  7847280609739507227  Organic Search    37832         Canada
# 5  1371078687799372953        Referral   478901  United States
# 6  8781227467221587011        Referral   119567  United States
# 7  7328657227470299189  Organic Search  1115991          India
# 8   603507101721972238        Referral    63158  United States
# 9  2410100047658323318          Direct   487916    New Zealand
#
#                             city  totalTransactionRevenue  transactions  \
# 0                      (not set)                      NaN           NaN
# 1  not available in demo dataset                      NaN           NaN
# ...
